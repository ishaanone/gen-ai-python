# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('matches.csv')

# %%
type(data)

# %%
# print(data)
data

# %%
data.head() # top 5 rows from dataframes

# %%
data.head(1)    #top first row

# %%
data.tail() # last/bottom 5 rows from dataframe

# %%
data.tail(1) # last row from dataframe

# %%
# how many entries are in dataframe
data.shape

# %%
data.info   # reference to the function

# %%
data.info() # quick summary of your dataset (DataFrame)

# %%
data.describe()   #method gives consise summary of dataframe(df)

# %%
data.head()
