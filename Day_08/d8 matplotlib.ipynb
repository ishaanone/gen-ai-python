# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
price = [10000, 12000, 13000, 14000, 13000, 12000]
year = [2015, 2016, 2017, 2018, 2019, 2020]

plt.plot(year, price)

# %%
batsman = pd.read_csv('sharma-kohli.csv')
batsman
#batsman[['index','RG Sharma']]
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
# create a line graph for rohit sharma

plt.plot(batsman['index'],batsman['RG Sharma'])

# %%
plt.plot(batsman['index'],batsman['V Kohli'])

# %%
#lets say i want compare them and see them side by side 

plt.plot(batsman['index'],batsman['RG Sharma'])
plt.plot(batsman['index'],batsman['V Kohli'])

# %%
##label and putting title

plt.plot(batsman['index'],batsman['RG Sharma'],color='green')
plt.plot(batsman['index'],batsman['V Kohli'],color='#345ceb')
plt.title('Rohit sharma va virat kohli career stats')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
#lets say we want dashed lines


plt.plot(batsman['index'],batsman['RG Sharma'],color='green',linestyle='dashed')
plt.plot(batsman['index'],batsman['V Kohli'],color='#345ceb', linestyle='dashdot')
plt.title('Rohit sharma va virat kohli career stats')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
#increase the line width

plt.plot(batsman['index'],batsman['RG Sharma'],color='green',linewidth=10)
plt.plot(batsman['index'],batsman['V Kohli'],color='#345ceb')
plt.title('Rohit sharma va virat kohli career stats')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
#Marker : A marker is a symbol used to represent each point on a plot

plt.plot(batsman['index'],batsman['RG Sharma'],color='green', marker='D',markerfacecolor='yellow')
plt.plot(batsman['index'],batsman['V Kohli'],color='#345ceb',marker='*', markersize=10,markerfacecolor='red')
plt.title('Rohit sharma va virat kohli career stats')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
#legends
# which line represents which player

plt.plot(batsman['index'],batsman['RG Sharma'],color='green', marker='D',markerfacecolor='yellow',label='ViratK')
plt.plot(batsman['index'],batsman['V Kohli'],color='#345ceb',marker='*', markersize=10,markerfacecolor='red',label='RohitS')
plt.legend()
plt.grid()
plt.title('Rohit sharma va virat kohli career stats')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
# lets say there is some outlier in the data
price = [10000, 12000, 13000, 14000, 13000, 1200000000]  # in year 2020 there is a outlier
year = [2015, 2016, 2017, 2018, 2019, 2020]

# %%
# lets trim the graph to make graph more readable
plt.ylim(9000,20000)  #only values between 9k to 20k will be shown
plt.xlim(2015,2019)  #only values betweeb 2015 to 2019 will be shown 
plt.plot(year, price, marker='o')

# %%
## there is float values in the x axis ...we need to remove it
plt.plot(year, price, marker='o')
plt.xlim(2015, 2019)
plt.ylim(9000,20000)



plt.xticks(year[:5])
plt.show()

# %%
#Scatter charts


x = [1,2,3,4,5]
y = [10,20,25,30,40]
plt.scatter(x,y)

plt.show() #show the graph (Optional)
